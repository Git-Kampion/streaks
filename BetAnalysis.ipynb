# %%
import pyodbc
import pandas as pd
conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:\Users\letenok\Documents\work\Flashscore\streaks\Database1.accdb')
cursor = conn.cursor()
insert_stmt = "select * from Epl where hhgoal > 0 OR ahgoal > 0"
data = ("Chelsea")
acMilanH = cursor.execute(insert_stmt)

output = []
team = ""
teamCount = 0
for row in acMilanH:
    print(row )  
    print(teamCount)  
    team = row[3]
    teamCount = 0
    for t in acMilanH:   
        if t[3] == team:
            teamCount = teamCount + 1
  
    #teamCount = teamCount + 1
# Out:
# 0

# %%
import pyodbc
import pandas as pd
conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:\Users\letenok\Documents\work\Flashscore\Database1.accdb')
cursor = conn.cursor()

#insert_stmt = "select * from SerieA where away = ? AND agoal > ?"
insert_stmt = "select * from BundasLiga1Germ"
Adata = ("0","0")

acMilanA = cursor.execute(insert_stmt)
#cursor.execute('select * from SerieA where home = "AcMilan"') AND ahgoal > ? AND hhgoal > ?    > ? OR ahgoal = ?  AND hhgoal > ? OR home = ? AND ahgoal > ?
#,"0","Augsburg","0" where  hgoal > hhgoal  or agoal > ahgoal
  

count = 0 
for pow in acMilanA:
        count = count + 1
        print(pow)
print(count)
# Out:
# (1, '34', '27.05.15:30', 'B.Monchengladbach', 'Augsburg', '2', '0', '2', '0')
# (2, '34', '27.05.15:30', 'Bochum', 'BayerLeverkusen', '3', '0', '2', '0')
# (3, '34', '27.05.15:30', 'Dortmund', 'Mainz', '2', '2', '0', '2')
# (4, '34', '27.05.15:30', 'EintrachtFrankfurt', 'Freiburg', '2', '1', '0', '1')
# (5, '34', '27.05.15:30', 'FCKoln', 'BayernMunich', '1', '2', '0', '1')
# (6, '34', '27.05.15:30', 'RBLeipzig', 'Schalke', '4', '2', '2', '1')
# (7, '34', '27.05.15:30', 'Stuttgart', 'Hoffenheim', '1', '1', '0', '0')
# (8, '34', '27.05.15:30', 'UnionBerlin', 'WerderBremen', '1', '0', '0', '0')
# (9, '34', '27.05.15:30', 'Wolfsburg', 'HerthaBerlin', '1', '2', '1', '0')
# (10, '33', '21.05.19:30', 'BayerLeverkusen', 'B.Monchengladbach', '2', '2', '2', '0')
# (11, '33', '21.05.17:30', 'Augsburg', 'Dortmund', '0', '3', '0', '0')
# (12, '33', '21.05.15:30', 'Mainz', 'Stuttgart', '1', '4', '1', '1')
# (13, '33', '20.05.18:30', 'BayernMunich', 'RBLeipzig', '1', '3', '1', '0')
# ...

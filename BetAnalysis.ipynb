# %%
import pyodbc
import pandas as pd
import sqlalchemy
import matplotlib.pyplot as plt 

engine = sqlalchemy.create_engine('mysql+pymysql://username:password@localhost:3306/db_name')

conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:\Users\letenok\Documents\work\Flashscore\streaks\Database1.accdb')
cursor = conn.cursor()

insert_stmt2 = "select * from Epl where hhgoal > 0 and hgoal > hhgoal"
data = ("Chelsea")
cursor.execute(insert_stmt2)
sql_data = pd.DataFrame(cursor.fetchall())
teamCount = 0


insert_stmt2 = "select * from Epl "
data = ("Chelsea")
cursor.execute(insert_stmt2)
sql_data2 = pd.DataFrame(cursor.fetchall())
teamCount = 0

teams = []
round = []
team = []
for ee in sql_data2[0]:
   if ee[3] in teams:
    t = ee[3]
   else:
    teams.append(ee[3])

for w in teams:
    t = w
    for k in sql_data[0]:
      if k[3] == t and t == "Arsenal":
         round.append(k[1])
         team.append(t)
        # print(k)
plt.plot(round, team) 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('Score both Halves') 
  
# function to show the plot 
plt.show()

# %%
import matplotlib.pyplot as plt 
x = [1,2,3] 
# corresponding y axis values 
y = [1,2,3,] 
# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('Score both Halves') 
  
# function to show the plot 
plt.show()

# %%
# Out:
# Arsenal 13
# AstonVilla 13
# Chelsea 5
# Leicester 10
# ManchesterUtd 13
# Southampton 5
# ManchesterUtd 13
# Brighton 9
# ManchesterCity 16
# Brighton 9
# WestHam 13
# Nottingham 12
# Fulham 10
# Wolves 9
# Tottenham 10
# Newcastle 8
# Brentford 11
# AstonVilla 13
# CrystalPalace 6
# ManchesterUtd 13
# Leeds 10
# Nottingham 12
# Fulham 10
# WestHam 13
# Liverpool 12
# Bournemouth 8
# ManchesterCity 16
# Tottenham 10
# Wolves 9
# Liverpool 12
# Arsenal 13
# Leicester 10
# Liverpool 12
# Bournemouth 8
# Fulham 10
# ManchesterUtd 13
# Brighton 9
# CrystalPalace 6
# ManchesterCity 16
# WestHam 13
# Nottingham 12
# Leeds 10
# AstonVilla 13
# Wolves 9
# Newcastle 8
# Leicester 10
# Arsenal 13
# WestHam 13
# ManchesterCity 16
# Chelsea 5
# Everton 6
# Tottenham 10
# Wolves 9
# AstonVilla 13
# Liverpool 12
# Leeds 10
# Brentford 11
# Tottenham 10
# Wolves 9
# ManchesterUtd 13
# ManchesterUtd 13
# WestHam 13
# Leeds 10
# Leicester 10
# WestHam 13
# Arsenal 13
